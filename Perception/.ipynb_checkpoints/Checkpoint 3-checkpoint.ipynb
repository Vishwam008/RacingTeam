# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from datetime import datetime
custom_date_parser = lambda x: datetime.strptime(x, "%d-%m-%Y")
df = pd.read_csv('forecast.csv')
df.head()
# Out:
#         Dates  Occupancy
# 0  27-01-2018          4
# 1  28-01-2018         11
# 2  29-01-2018         10
# 3  30-01-2018          9
# 4  31-01-2018          9

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Dates      1600 non-null   datetime64[ns]
#  1   Occupancy  1600 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 25.1 KB

# %%
df.shape
# Out:
# (1600, 1)

# %%
from pmdarima import auto_arima
  
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
  
# Fit auto_arima function to AirPassengers dataset
stepwise_fit = auto_arima(df['Occupancy'], start_p = 1, start_q = 1,
                          max_p = 3, max_q = 3, m = 12,
                          start_P = 0, seasonal = True,
                          d = None, D = 1, trace = True,
                          error_action ='ignore',   # we don't want to know if an order does not work
                          suppress_warnings = True,  # we don't want convergence warnings
                          stepwise = True)           # set to stepwise
  
# To print the summary
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=3.51 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=13477.536, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=12160.694, Time=1.23 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=11974.418, Time=1.09 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=13475.563, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=12574.220, Time=0.32 sec
#  ARIMA(0,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=3.66 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=11945.621, Time=3.41 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=10.12 sec
#  ARIMA(0,0,0)(0,1,2)[12] intercept   : AIC=12960.520, Time=2.53 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=inf, Time=9.04 sec
#  ARIMA(0,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=10.60 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=8.19 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=15.82 sec
#  ARIMA(0,0,1)(0,1,2)[12]             : AIC=11945.926, Time=3.07 sec
#
# Best model:  ARIMA(0,0,1)(0,1,2)[12] intercept
# Total fit time: 72.755 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                 1600
# Model:             SARIMAX(0, 0, 1)x(0, 1, [1, 2], 12)   Log Likelihood               -5967.810
# Date:                                 Wed, 31 May 2023   AIC                          11945.621
# Time:                                         23:34:31   BIC                          11972.472
# Sample:                                              0   HQIC                         11955.595
#                                                 - 1600
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0994      0.070      1.410      0.158      -0.039       0.237
# ma.L1          0.6982      0.015     46.584      0.000       0.669       0.728
# ma.S.L12      -0.6940      0.021    -33.162      0.000      -0.735      -0.653
# ma.S.L24      -0.1687      0.021     -7.915      0.000      -0.210      -0.127
# sigma2       106.5234      3.127     34.063      0.000     100.394     112.653
# ===================================================================================
# Ljung-Box (L1) (Q):                 151.94   Jarque-Bera (JB):               335.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                             0.79
# Prob(H) (two-sided):                  0.72   Kurtosis:                         4.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train = df.iloc[:-480]
test = df.iloc[-480:] # set one year(12 months) for testing
  
# Fit a SARIMAX(0, 1, 1)x(2, 1, 1, 12) on the training set
from statsmodels.tsa.statespace.sarimax import SARIMAX
  
model = SARIMAX(train['Occupancy'], 
                order = (1, 1, 0), 
                seasonal_order =(2, 1, 1, 365))
  
result = model.fit()
result.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.75238D+00    |proj g|=  7.27029D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.61778D+00    |proj g|=  1.36916D-01
#
# At iterate   10    f=  3.59601D+00    |proj g|=  2.30118D-03
#
# At iterate   15    f=  3.59600D+00    |proj g|=  1.77177D-03
#
# At iterate   20    f=  3.59578D+00    |proj g|=  2.74360D-03
#
# At iterate   25    f=  3.59572D+00    |proj g|=  6.13995D-04
#
# At iterate   30    f=  3.59572D+00    |proj g|=  1.08422D-04
#
# At iterate   35    f=  3.59571D+00    |proj g|=  1.78163D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     39     43      1     0     0   6.342D-05   3.596D+00
#   F =   3.5957145683580101
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Occupancy   No. Observations:                 1120
# Model:             SARIMAX(0, 1, 1)x(2, 1, 1, 12)   Log Likelihood               -4027.200
# Date:                            Wed, 31 May 2023   AIC                           8064.401
# Time:                                    23:43:31   BIC                           8089.448
# Sample:                                         0   HQIC                          8073.873
#                                            - 1120
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0512      0.022     -2.349      0.019      -0.094      -0.008
# ar.S.L12      -0.0414      0.026     -1.572      0.116      -0.093       0.010
# ar.S.L24      -0.1335      0.028     -4.780      0.000      -0.188      -0.079
# ma.S.L12      -0.9999      2.133     -0.469      0.639      -5.180       3.180
# sigma2        80.2371    170.525      0.471      0.638    -253.986     414.461
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):               343.88
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.13   Skew:                             0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# %matplotlib notebook

# %%
start = len(train)
end = len(train) + len(test) - 1
print(start, end)
# Predictions for one-year against the test set
predictions = result.predict(start, end,
                             typ = 'levels').rename("Predictions")
  
# plot predictions and actual values
predictions.plot(legend = True)
test['Occupancy'].plot(legend = True)
print(predictions)
# Out:
# 1120 1599
# <img src="data:image/png;base64,..." width="640">
# 1120    31.882274
# 1121    32.922635
# 1122    35.585222
# 1123    33.769271
# 1124    34.113269
#           ...
# 1595    42.489274
# 1596    40.972209
# 1597    42.614274
# 1598    43.967536
# 1599    43.803661
# Name: Predictions, Length: 480, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
  
# Calculate root mean squared error
print(rmse(test["Occupancy"], predictions))
  
# Calculate mean squared error
mean_squared_error(test["Occupancy"], predictions)
# Out:
# 19.525279302247853
# 381.23653183078835
